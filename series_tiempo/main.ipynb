# %%
import pandas as pd

# %%
df = pd.read_csv("competidores\Competidor1.csv")
df["Competidor"] = "C1"
df
# Out:
#           YMD   Product1    Product2  Time Competidor
# 0    20190106  2408555.0  12372749.0     1         C1
# 1    20190113  2215418.0  12374756.3     2         C1
# 2    20190120  2167294.0  13203648.2     3         C1
# 3    20190127  2173777.0  12319799.4     4         C1
# 4    20190203  2312097.0  12948943.7     5         C1
# ..        ...        ...         ...   ...        ...
# 170  20220401  1710449.0  11498573.0   171         C1
# 171  20220410  1750463.0  12136365.0   172         C1
# 172  20220417  1780374.0  11433778.5   173         C1
# 173  20220424  1889885.0  10819595.0   174         C1
# 174  20220508  1798562.0  12266624.5   175         C1
#
# [175 rows x 5 columns]

# %%
for i in range(2,11):
    temp = pd.read_csv("competidores\Competidor"+str(2)+".csv")
    temp["Competidor"] = "C" + str(i)
    df = pd.concat([df, temp])
    

#df["YMD"][:10] = pd.to_datetime(df["YMD"][:10], format="%Y%m%d")
df
# Out:
#           YMD    Product1    Product2  Time Competidor
# 0    20190106   2408555.0  12372749.0     1         C1
# 1    20190113   2215418.0  12374756.3     2         C1
# 2    20190120   2167294.0  13203648.2     3         C1
# 3    20190127   2173777.0  12319799.4     4         C1
# 4    20190203   2312097.0  12948943.7     5         C1
# ..        ...         ...         ...   ...        ...
# 170  20220401  38060121.5         NaN   171        C10
# 171  20220410  38301684.5         NaN   172        C10
# 172  20220417  37199508.5         NaN   173        C10
# 173  20220424  37747067.5         NaN   174        C10
# 174  20220508  38826079.5         NaN   175        C10
#
# [1750 rows x 5 columns]

# %%
pd.to_datetime(df["YMD"].apply(str), format="%Y%m%d")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\chccr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509         try:
# --> 510             values, tz = conversion.datetime_to_datetime64(arg)
#     511             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# c:\Users\chccr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18556\355795346.py in <module>
# ...

# %%
type(df["YMD"].values[0])
# Out:
# numpy.int64
